# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from operator import itemgetter

# %%
# Read in English dataset
english = '../datasets/cmudict.dict'
data = []
with open(english, 'r') as infile:
        for line in infile:
                    data.append((line.rstrip('\n').split(' ')))
data[:5]
# Out:
# [["'bout", 'B', 'AW1', 'T'],
#  ["'cause", 'K', 'AH0', 'Z'],
#  ["'course", 'K', 'AO1', 'R', 'S'],
#  ["'cuse", 'K', 'Y', 'UW1', 'Z'],
#  ["'em", 'AH0', 'M']]

# %%
# There were words included that weren't in English, so removing those and storing elsewhere for now
not_english = []
for item in data:
    if '#' in item:
        not_english.append('item')
        data.remove(item)

# %%
# Adding a stop character to the end of each word
for item in data:
    item.append('stop')

# %%
# Extending the data so each word incrementally gains one of its phonemes
extended_data = []
for item in data:
        for i in range(len(item)-1):
            extended_data.append(item[:i+2])

# %%
extended_data
# Out:
# [["'bout", 'B'],
#  ["'bout", 'B', 'AW1'],
#  ["'bout", 'B', 'AW1', 'T'],
#  ["'bout", 'B', 'AW1', 'T', 'stop'],
#  ["'cause", 'K'],
#  ["'cause", 'K', 'AH0'],
#  ["'cause", 'K', 'AH0', 'Z'],
#  ["'cause", 'K', 'AH0', 'Z', 'stop'],
#  ["'course", 'K'],
#  ["'course", 'K', 'AO1'],
#  ["'course", 'K', 'AO1', 'R'],
#  ["'course", 'K', 'AO1', 'R', 'S'],
#  ["'course", 'K', 'AO1', 'R', 'S', 'stop'],
#  ["'cuse", 'K'],
#  ["'cuse", 'K', 'Y'],
#  ["'cuse", 'K', 'Y', 'UW1'],
#  ["'cuse", 'K', 'Y', 'UW1', 'Z'],
#  ["'cuse", 'K', 'Y', 'UW1', 'Z', 'stop'],
#  ["'em", 'AH0'],
#  ["'em", 'AH0', 'M'],
#  ["'em", 'AH0', 'M', 'stop'],
#  ["'frisco", 'F'],
#  ["'frisco", 'F', 'R'],
#  ["'frisco", 'F', 'R', 'IH1'],
#  ["'frisco", 'F', 'R', 'IH1', 'S'],
#  ["'frisco", 'F', 'R', 'IH1', 'S', 'K'],
#  ["'frisco", 'F', 'R', 'IH1', 'S', 'K', 'OW0'],
#  ["'frisco", 'F', 'R', 'IH1', 'S', 'K', 'OW0', 'stop'],
#  ["'gain", 'G'],
#  ["'gain", 'G', 'EH1'],
#  ["'gain", 'G', 'EH1', 'N'],
#  ["'gain", 'G', 'EH1', 'N', 'stop'],
#  ["'kay", 'K'],
#  ["'kay", 'K', 'EY1'],
#  ["'kay", 'K', 'EY1', 'stop'],
#  ["'m", 'AH0'],
#  ["'m", 'AH0', 'M'],
#  ["'m", 'AH0', 'M', 'stop'],
#  ["'n", 'AH0'],
#  ["'n", 'AH0', 'N'],
#  ["'n", 'AH0', 'N', 'stop'],
#  ["'round", 'R'],
#  ["'round", 'R', 'AW1'],
#  ["'round", 'R', 'AW1', 'N'],
#  ["'round", 'R', 'AW1', 'N', 'D'],
#  ["'round", 'R', 'AW1', 'N', 'D', 'stop'],
#  ["'s", 'EH1'],
#  ["'s", 'EH1', 'S'],
#  ["'s", 'EH1', 'S', 'stop'],
#  ["'til", 'T'],
#  ["'til", 'T', 'IH1'],
#  ["'til", 'T', 'IH1', 'L'],
#  ["'til", 'T', 'IH1', 'L', 'stop'],
#  ["'tis", 'T'],
#  ["'tis", 'T', 'IH1'],
#  ["'tis", 'T', 'IH1', 'Z'],
#  ["'tis", 'T', 'IH1', 'Z', 'stop'],
#  ["'twas", 'T'],
#  ["'twas", 'T', 'W'],
#  ["'twas", 'T', 'W', 'AH1'],
#  ["'twas", 'T', 'W', 'AH1', 'Z'],
#  ["'twas", 'T', 'W', 'AH1', 'Z', 'stop'],
#  ['a', 'AH0'],
#  ['a', 'AH0', 'stop'],
#  ['a(2)', 'EY1'],
#  ['a(2)', 'EY1', 'stop'],
#  ["a's", 'EY1'],
#  ["a's", 'EY1', 'Z'],
#  ["a's", 'EY1', 'Z', 'stop'],
#  ['a.', 'EY1'],
#  ['a.', 'EY1', 'stop'],
#  ["a.'s", 'EY1'],
#  ["a.'s", 'EY1', 'Z'],
#  ["a.'s", 'EY1', 'Z', 'stop'],
#  ['a.d.', 'EY2'],
#  ['a.d.', 'EY2', 'D'],
#  ['a.d.', 'EY2', 'D', 'IY1'],
#  ['a.d.', 'EY2', 'D', 'IY1', 'stop'],
#  ['a.m.', 'EY2'],
#  ['a.m.', 'EY2', 'EH1'],
#  ['a.m.', 'EY2', 'EH1', 'M'],
#  ['a.m.', 'EY2', 'EH1', 'M', 'stop'],
#  ['a.s', 'EY1'],
#  ['a.s', 'EY1', 'Z'],
#  ['a.s', 'EY1', 'Z', 'stop'],
#  ['aaa', 'T'],
#  ['aaa', 'T', 'R'],
#  ['aaa', 'T', 'R', 'IH2'],
#  ['aaa', 'T', 'R', 'IH2', 'P'],
#  ['aaa', 'T', 'R', 'IH2', 'P', 'AH0'],
#  ['aaa', 'T', 'R', 'IH2', 'P', 'AH0', 'L'],
#  ['aaa', 'T', 'R', 'IH2', 'P', 'AH0', 'L', 'EY1'],
#  ['aaa', 'T', 'R', 'IH2', 'P', 'AH0', 'L', 'EY1', 'stop'],
#  ['aaberg', 'AA1'],
#  ['aaberg', 'AA1', 'B'],
#  ['aaberg', 'AA1', 'B', 'ER0'],
#  ['aaberg', 'AA1', 'B', 'ER0', 'G'],
#  ['aaberg', 'AA1', 'B', 'ER0', 'G', 'stop'],
#  ['aachen', 'AA1'],
#  ['aachen', 'AA1', 'K'],
#  ['aachen', 'AA1', 'K', 'AH0'],
#  ['aachen', 'AA1', 'K', 'AH0', 'N'],
#  ['aachen', 'AA1', 'K', 'AH0', 'N', 'stop'],
#  ['aachener', 'AA1'],
#  ['aachener', 'AA1', 'K'],
#  ['aachener', 'AA1', 'K', 'AH0'],
#  ['aachener', 'AA1', 'K', 'AH0', 'N'],
#  ['aachener', 'AA1', 'K', 'AH0', 'N', 'ER0'],
#  ['aachener', 'AA1', 'K', 'AH0', 'N', 'ER0', 'stop'],
#  ['aaker', 'AA1'],
#  ['aaker', 'AA1', 'K'],
#  ['aaker', 'AA1', 'K', 'ER0'],
#  ['aaker', 'AA1', 'K', 'ER0', 'stop'],
#  ['aalborg(2)', 'AA1'],
#  ['aalborg(2)', 'AA1', 'L'],
#  ['aalborg(2)', 'AA1', 'L', 'B'],
#  ['aalborg(2)', 'AA1', 'L', 'B', 'AO0'],
#  ['aalborg(2)', 'AA1', 'L', 'B', 'AO0', 'R'],
#  ['aalborg(2)', 'AA1', 'L', 'B', 'AO0', 'R', 'G'],
#  ['aalborg(2)', 'AA1', 'L', 'B', 'AO0', 'R', 'G', 'stop'],
#  ['aalen', 'AE1'],
#  ['aalen', 'AE1', 'L'],
#  ['aalen', 'AE1', 'L', 'AH0'],
#  ['aalen', 'AE1', 'L', 'AH0', 'N'],
#  ['aalen', 'AE1', 'L', 'AH0', 'N', '#'],
#  ['aalen', 'AE1', 'L', 'AH0', 'N', '#', 'place,'],
#  ['aalen', 'AE1', 'L', 'AH0', 'N', '#', 'place,', 'german'],
#  ['aalen', 'AE1', 'L', 'AH0', 'N', '#', 'place,', 'german', 'stop'],
#  ['aalen(2)', 'AA1'],
#  ['aalen(2)', 'AA1', 'L'],
#  ['aalen(2)', 'AA1', 'L', 'AH0'],
#  ['aalen(2)', 'AA1', 'L', 'AH0', 'N'],
#  ['aalen(2)', 'AA1', 'L', 'AH0', 'N', 'stop'],
#  ['aaliyah', 'AA2'],
#  ['aaliyah', 'AA2', 'L'],
#  ['aaliyah', 'AA2', 'L', 'IY1'],
#  ['aaliyah', 'AA2', 'L', 'IY1', 'AA2'],
#  ['aaliyah', 'AA2', 'L', 'IY1', 'AA2', 'stop'],
#  ['aalseth', 'AA1'],
#  ['aalseth', 'AA1', 'L'],
#  ['aalseth', 'AA1', 'L', 'S'],
#  ['aalseth', 'AA1', 'L', 'S', 'EH0'],
#  ['aalseth', 'AA1', 'L', 'S', 'EH0', 'TH'],
#  ['aalseth', 'AA1', 'L', 'S', 'EH0', 'TH', 'stop'],
#  ['aalto', 'AA1'],
#  ['aalto', 'AA1', 'L'],
#  ['aalto', 'AA1', 'L', 'T'],
#  ['aalto', 'AA1', 'L', 'T', 'OW2'],
#  ['aalto', 'AA1', 'L', 'T', 'OW2', '#'],
#  ['aalto', 'AA1', 'L', 'T', 'OW2', '#', 'name,'],
#  ['aalto', 'AA1', 'L', 'T', 'OW2', '#', 'name,', 'finnish'],
#  ['aalto', 'AA1', 'L', 'T', 'OW2', '#', 'name,', 'finnish', 'stop'],
#  ['aamodt', 'AA1'],
#  ['aamodt', 'AA1', 'M'],
#  ['aamodt', 'AA1', 'M', 'AH0'],
#  ['aamodt', 'AA1', 'M', 'AH0', 'T'],
#  ['aamodt', 'AA1', 'M', 'AH0', 'T', 'stop'],
#  ['aancor', 'AA1'],
#  ['aancor', 'AA1', 'N'],
#  ['aancor', 'AA1', 'N', 'K'],
#  ['aancor', 'AA1', 'N', 'K', 'AO2'],
#  ['aancor', 'AA1', 'N', 'K', 'AO2', 'R'],
#  ['aancor', 'AA1', 'N', 'K', 'AO2', 'R', 'stop'],
#  ['aardema', 'AA0'],
#  ['aardema', 'AA0', 'R'],
#  ['aardema', 'AA0', 'R', 'D'],
#  ['aardema', 'AA0', 'R', 'D', 'EH1'],
#  ['aardema', 'AA0', 'R', 'D', 'EH1', 'M'],
#  ['aardema', 'AA0', 'R', 'D', 'EH1', 'M', 'AH0'],
#  ['aardema', 'AA0', 'R', 'D', 'EH1', 'M', 'AH0', 'stop'],
#  ['aardvark', 'AA1'],
#  ['aardvark', 'AA1', 'R'],
#  ['aardvark', 'AA1', 'R', 'D'],
#  ['aardvark', 'AA1', 'R', 'D', 'V'],
#  ['aardvark', 'AA1', 'R', 'D', 'V', 'AA2'],
#  ['aardvark', 'AA1', 'R', 'D', 'V', 'AA2', 'R'],
#  ['aardvark', 'AA1', 'R', 'D', 'V', 'AA2', 'R', 'K'],
#  ['aardvark', 'AA1', 'R', 'D', 'V', 'AA2', 'R', 'K', 'stop'],
#  ['aardvarks', 'AA1'],
#  ['aardvarks', 'AA1', 'R'],
#  ['aardvarks', 'AA1', 'R', 'D'],
#  ['aardvarks', 'AA1', 'R', 'D', 'V'],
#  ['aardvarks', 'AA1', 'R', 'D', 'V', 'AA2'],
#  ['aardvarks', 'AA1', 'R', 'D', 'V', 'AA2', 'R'],
#  ['aardvarks', 'AA1', 'R', 'D', 'V', 'AA2', 'R', 'K'],
#  ['aardvarks', 'AA1', 'R', 'D', 'V', 'AA2', 'R', 'K', 'S'],
#  ['aardvarks', 'AA1', 'R', 'D', 'V', 'AA2', 'R', 'K', 'S', 'stop'],
#  ['aargh', 'AA1'],
#  ['aargh', 'AA1', 'R'],
#  ['aargh', 'AA1', 'R', 'G'],
#  ['aargh', 'AA1', 'R', 'G', 'stop'],
#  ['aarhus', 'AA2'],
#  ['aarhus', 'AA2', 'HH'],
#  ['aarhus', 'AA2', 'HH', 'UW1'],
#  ['aarhus', 'AA2', 'HH', 'UW1', 'S'],
#  ['aarhus', 'AA2', 'HH', 'UW1', 'S', 'stop'],
#  ['aaron', 'EH1'],
#  ['aaron', 'EH1', 'R'],
#  ['aaron', 'EH1', 'R', 'AH0'],
#  ['aaron', 'EH1', 'R', 'AH0', 'N'],
#  ['aaron', 'EH1', 'R', 'AH0', 'N', 'stop'],
#  ["aaron's", 'EH1'],
#  ["aaron's", 'EH1', 'R'],
#  ["aaron's", 'EH1', 'R', 'AH0'],
#  ["aaron's", 'EH1', 'R', 'AH0', 'N'],
#  ["aaron's", 'EH1', 'R', 'AH0', 'N', 'Z'],
#  ["aaron's", 'EH1', 'R', 'AH0', 'N', 'Z', 'stop'],
#  ['aarons', 'EH1'],
#  ['aarons', 'EH1', 'R'],
#  ['aarons', 'EH1', 'R', 'AH0'],
#  ['aarons', 'EH1', 'R', 'AH0', 'N'],
#  ['aarons', 'EH1', 'R', 'AH0', 'N', 'Z'],
#  ['aarons', 'EH1', 'R', 'AH0', 'N', 'Z', 'stop'],
#  ['aaronson', 'EH1'],
#  ['aaronson', 'EH1', 'R'],
#  ['aaronson', 'EH1', 'R', 'AH0'],
#  ['aaronson', 'EH1', 'R', 'AH0', 'N'],
#  ['aaronson', 'EH1', 'R', 'AH0', 'N', 'S'],
#  ['aaronson', 'EH1', 'R', 'AH0', 'N', 'S', 'AH0'],
#  ['aaronson', 'EH1', 'R', 'AH0', 'N', 'S', 'AH0', 'N'],
#  ['aaronson', 'EH1', 'R', 'AH0', 'N', 'S', 'AH0', 'N', 'stop'],
#  ['aaronson(2)', 'AA1'],
#  ['aaronson(2)', 'AA1', 'R'],
#  ['aaronson(2)', 'AA1', 'R', 'AH0'],
#  ['aaronson(2)', 'AA1', 'R', 'AH0', 'N'],
#  ['aaronson(2)', 'AA1', 'R', 'AH0', 'N', 'S'],
#  ['aaronson(2)', 'AA1', 'R', 'AH0', 'N', 'S', 'AH0'],
#  ['aaronson(2)', 'AA1', 'R', 'AH0', 'N', 'S', 'AH0', 'N'],
#  ['aaronson(2)', 'AA1', 'R', 'AH0', 'N', 'S', 'AH0', 'N', 'stop'],
#  ["aaronson's", 'EH1'],
#  ["aaronson's", 'EH1', 'R'],
#  ["aaronson's", 'EH1', 'R', 'AH0'],
#  ["aaronson's", 'EH1', 'R', 'AH0', 'N'],
#  ["aaronson's", 'EH1', 'R', 'AH0', 'N', 'S'],
#  ["aaronson's", 'EH1', 'R', 'AH0', 'N', 'S', 'AH0'],
#  ["aaronson's", 'EH1', 'R', 'AH0', 'N', 'S', 'AH0', 'N'],
#  ["aaronson's", 'EH1', 'R', 'AH0', 'N', 'S', 'AH0', 'N', 'Z'],
#  ["aaronson's", 'EH1', 'R', 'AH0', 'N', 'S', 'AH0', 'N', 'Z', 'stop'],
#  ["aaronson's(2)", 'AA1'],
#  ["aaronson's(2)", 'AA1', 'R'],
#  ["aaronson's(2)", 'AA1', 'R', 'AH0'],
#  ["aaronson's(2)", 'AA1', 'R', 'AH0', 'N'],
#  ["aaronson's(2)", 'AA1', 'R', 'AH0', 'N', 'S'],
#  ["aaronson's(2)", 'AA1', 'R', 'AH0', 'N', 'S', 'AH0'],
#  ["aaronson's(2)", 'AA1', 'R', 'AH0', 'N', 'S', 'AH0', 'N'],
#  ["aaronson's(2)", 'AA1', 'R', 'AH0', 'N', 'S', 'AH0', 'N', 'Z'],
#  ["aaronson's(2)", 'AA1', 'R', 'AH0', 'N', 'S', 'AH0', 'N', 'Z', 'stop'],
#  ['aarti', 'AA1'],
#  ['aarti', 'AA1', 'R'],
#  ['aarti', 'AA1', 'R', 'T'],
#  ['aarti', 'AA1', 'R', 'T', 'IY2'],
#  ['aarti', 'AA1', 'R', 'T', 'IY2', 'stop'],
#  ['aase', 'AA1'],
#  ['aase', 'AA1', 'S'],
#  ['aase', 'AA1', 'S', 'stop'],
#  ['aasen', 'AA1'],
#  ['aasen', 'AA1', 'S'],
#  ['aasen', 'AA1', 'S', 'AH0'],
#  ['aasen', 'AA1', 'S', 'AH0', 'N'],
#  ['aasen', 'AA1', 'S', 'AH0', 'N', 'stop'],
#  ['ab', 'AE1'],
#  ['ab', 'AE1', 'B'],
#  ['ab', 'AE1', 'B', 'stop'],
#  ['ab(2)', 'EY1'],
#  ['ab(2)', 'EY1', 'B'],
#  ['ab(2)', 'EY1', 'B', 'IY1'],
#  ['ab(2)', 'EY1', 'B', 'IY1', 'stop'],
#  ['aba', 'EY2'],
#  ['aba', 'EY2', 'B'],
#  ['aba', 'EY2', 'B', 'IY2'],
#  ['aba', 'EY2', 'B', 'IY2', 'EY1'],
#  ['aba', 'EY2', 'B', 'IY2', 'EY1', 'stop'],
#  ['ababa', 'AH0'],
#  ['ababa', 'AH0', 'B'],
#  ['ababa', 'AH0', 'B', 'AA1'],
#  ['ababa', 'AH0', 'B', 'AA1', 'B'],
#  ['ababa', 'AH0', 'B', 'AA1', 'B', 'AH0'],
#  ['ababa', 'AH0', 'B', 'AA1', 'B', 'AH0', 'stop'],
#  ['ababa(2)', 'AA1'],
#  ['ababa(2)', 'AA1', 'B'],
#  ['ababa(2)', 'AA1', 'B', 'AH0'],
#  ['ababa(2)', 'AA1', 'B', 'AH0', 'B'],
#  ['ababa(2)', 'AA1', 'B', 'AH0', 'B', 'AH0'],
#  ['ababa(2)', 'AA1', 'B', 'AH0', 'B', 'AH0', 'stop'],
#  ['abacha', 'AE1'],
#  ['abacha', 'AE1', 'B'],
#  ['abacha', 'AE1', 'B', 'AH0'],
#  ['abacha', 'AE1', 'B', 'AH0', 'K'],
#  ['abacha', 'AE1', 'B', 'AH0', 'K', 'AH0'],
#  ['abacha', 'AE1', 'B', 'AH0', 'K', 'AH0', 'stop'],
#  ['aback', 'AH0'],
#  ['aback', 'AH0', 'B'],
#  ['aback', 'AH0', 'B', 'AE1'],
#  ['aback', 'AH0', 'B', 'AE1', 'K'],
#  ['aback', 'AH0', 'B', 'AE1', 'K', 'stop'],
#  ['abaco', 'AE1'],
#  ['abaco', 'AE1', 'B'],
#  ['abaco', 'AE1', 'B', 'AH0'],
#  ['abaco', 'AE1', 'B', 'AH0', 'K'],
#  ['abaco', 'AE1', 'B', 'AH0', 'K', 'OW2'],
#  ['abaco', 'AE1', 'B', 'AH0', 'K', 'OW2', 'stop'],
#  ['abacus', 'AE1'],
#  ['abacus', 'AE1', 'B'],
#  ['abacus', 'AE1', 'B', 'AH0'],
#  ['abacus', 'AE1', 'B', 'AH0', 'K'],
#  ['abacus', 'AE1', 'B', 'AH0', 'K', 'AH0'],
#  ['abacus', 'AE1', 'B', 'AH0', 'K', 'AH0', 'S'],
#  ['abacus', 'AE1', 'B', 'AH0', 'K', 'AH0', 'S', 'stop'],
#  ['abad', 'AH0'],
#  ['abad', 'AH0', 'B'],
#  ['abad', 'AH0', 'B', 'AA1'],
#  ['abad', 'AH0', 'B', 'AA1', 'D'],
#  ['abad', 'AH0', 'B', 'AA1', 'D', 'stop'],
#  ['abadaka', 'AH0'],
#  ['abadaka', 'AH0', 'B'],
#  ['abadaka', 'AH0', 'B', 'AE1'],
#  ['abadaka', 'AH0', 'B', 'AE1', 'D'],
#  ['abadaka', 'AH0', 'B', 'AE1', 'D', 'AH0'],
#  ['abadaka', 'AH0', 'B', 'AE1', 'D', 'AH0', 'K'],
#  ['abadaka', 'AH0', 'B', 'AE1', 'D', 'AH0', 'K', 'AH0'],
#  ['abadaka', 'AH0', 'B', 'AE1', 'D', 'AH0', 'K', 'AH0', 'stop'],
#  ['abadi', 'AH0'],
#  ['abadi', 'AH0', 'B'],
#  ['abadi', 'AH0', 'B', 'AE1'],
#  ['abadi', 'AH0', 'B', 'AE1', 'D'],
#  ['abadi', 'AH0', 'B', 'AE1', 'D', 'IY0'],
#  ['abadi', 'AH0', 'B', 'AE1', 'D', 'IY0', 'stop'],
#  ['abadie', 'AH0'],
#  ['abadie', 'AH0', 'B'],
#  ['abadie', 'AH0', 'B', 'AE1'],
#  ['abadie', 'AH0', 'B', 'AE1', 'D'],
#  ['abadie', 'AH0', 'B', 'AE1', 'D', 'IY0'],
#  ['abadie', 'AH0', 'B', 'AE1', 'D', 'IY0', 'stop'],
#  ['abair', 'AH0'],
#  ['abair', 'AH0', 'B'],
#  ['abair', 'AH0', 'B', 'EH1'],
#  ['abair', 'AH0', 'B', 'EH1', 'R'],
#  ['abair', 'AH0', 'B', 'EH1', 'R', 'stop'],
#  ['abalkin', 'AH0'],
#  ['abalkin', 'AH0', 'B'],
#  ['abalkin', 'AH0', 'B', 'AA1'],
#  ['abalkin', 'AH0', 'B', 'AA1', 'L'],
#  ['abalkin', 'AH0', 'B', 'AA1', 'L', 'K'],
#  ['abalkin', 'AH0', 'B', 'AA1', 'L', 'K', 'IH0'],
#  ['abalkin', 'AH0', 'B', 'AA1', 'L', 'K', 'IH0', 'N'],
#  ['abalkin', 'AH0', 'B', 'AA1', 'L', 'K', 'IH0', 'N', 'stop'],
#  ['abalone', 'AE2'],
#  ['abalone', 'AE2', 'B'],
#  ['abalone', 'AE2', 'B', 'AH0'],
#  ['abalone', 'AE2', 'B', 'AH0', 'L'],
#  ['abalone', 'AE2', 'B', 'AH0', 'L', 'OW1'],
#  ['abalone', 'AE2', 'B', 'AH0', 'L', 'OW1', 'N'],
#  ['abalone', 'AE2', 'B', 'AH0', 'L', 'OW1', 'N', 'IY0'],
#  ['abalone', 'AE2', 'B', 'AH0', 'L', 'OW1', 'N', 'IY0', 'stop'],
#  ['abalones', 'AE2'],
#  ['abalones', 'AE2', 'B'],
#  ['abalones', 'AE2', 'B', 'AH0'],
#  ['abalones', 'AE2', 'B', 'AH0', 'L'],
#  ['abalones', 'AE2', 'B', 'AH0', 'L', 'OW1'],
#  ['abalones', 'AE2', 'B', 'AH0', 'L', 'OW1', 'N'],
#  ['abalones', 'AE2', 'B', 'AH0', 'L', 'OW1', 'N', 'IY0'],
#  ['abalones', 'AE2', 'B', 'AH0', 'L', 'OW1', 'N', 'IY0', 'Z'],
#  ['abalones', 'AE2', 'B', 'AH0', 'L', 'OW1', 'N', 'IY0', 'Z', 'stop'],
#  ['abalos', 'AA0'],
#  ['abalos', 'AA0', 'B'],
#  ['abalos', 'AA0', 'B', 'AA1'],
#  ['abalos', 'AA0', 'B', 'AA1', 'L'],
#  ['abalos', 'AA0', 'B', 'AA1', 'L', 'OW0'],
#  ['abalos', 'AA0', 'B', 'AA1', 'L', 'OW0', 'Z'],
#  ['abalos', 'AA0', 'B', 'AA1', 'L', 'OW0', 'Z', 'stop'],
#  ['abandon', 'AH0'],
#  ['abandon', 'AH0', 'B'],
#  ['abandon', 'AH0', 'B', 'AE1'],
#  ['abandon', 'AH0', 'B', 'AE1', 'N'],
#  ['abandon', 'AH0', 'B', 'AE1', 'N', 'D'],
#  ['abandon', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0'],
#  ['abandon', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N'],
#  ['abandon', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'stop'],
#  ['abandoned', 'AH0'],
#  ['abandoned', 'AH0', 'B'],
#  ['abandoned', 'AH0', 'B', 'AE1'],
#  ['abandoned', 'AH0', 'B', 'AE1', 'N'],
#  ['abandoned', 'AH0', 'B', 'AE1', 'N', 'D'],
#  ['abandoned', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0'],
#  ['abandoned', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N'],
#  ['abandoned', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'D'],
#  ['abandoned', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'D', 'stop'],
#  ['abandoning', 'AH0'],
#  ['abandoning', 'AH0', 'B'],
#  ['abandoning', 'AH0', 'B', 'AE1'],
#  ['abandoning', 'AH0', 'B', 'AE1', 'N'],
#  ['abandoning', 'AH0', 'B', 'AE1', 'N', 'D'],
#  ['abandoning', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0'],
#  ['abandoning', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N'],
#  ['abandoning', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'IH0'],
#  ['abandoning', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'IH0', 'NG'],
#  ['abandoning', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'IH0', 'NG', 'stop'],
#  ['abandonment', 'AH0'],
#  ['abandonment', 'AH0', 'B'],
#  ['abandonment', 'AH0', 'B', 'AE1'],
#  ['abandonment', 'AH0', 'B', 'AE1', 'N'],
#  ['abandonment', 'AH0', 'B', 'AE1', 'N', 'D'],
#  ['abandonment', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0'],
#  ['abandonment', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N'],
#  ['abandonment', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'M'],
#  ['abandonment', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'M', 'AH0'],
#  ['abandonment', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'M', 'AH0', 'N'],
#  ['abandonment',
#   'AH0',
#   'B',
#   'AE1',
#   'N',
#   'D',
#   'AH0',
#   'N',
#   'M',
#   'AH0',
#   'N',
#   'T'],
#  ['abandonment',
#   'AH0',
#   'B',
#   'AE1',
#   'N',
#   'D',
#   'AH0',
#   'N',
#   'M',
#   'AH0',
#   'N',
#   'T',
#   'stop'],
#  ['abandonments', 'AH0'],
#  ['abandonments', 'AH0', 'B'],
#  ['abandonments', 'AH0', 'B', 'AE1'],
#  ['abandonments', 'AH0', 'B', 'AE1', 'N'],
#  ['abandonments', 'AH0', 'B', 'AE1', 'N', 'D'],
#  ['abandonments', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0'],
#  ['abandonments', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N'],
#  ['abandonments', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'M'],
#  ['abandonments', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'M', 'AH0'],
#  ['abandonments', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'M', 'AH0', 'N'],
#  ['abandonments',
#   'AH0',
#   'B',
#   'AE1',
#   'N',
#   'D',
#   'AH0',
#   'N',
#   'M',
#   'AH0',
#   'N',
#   'T'],
#  ['abandonments',
#   'AH0',
#   'B',
#   'AE1',
#   'N',
#   'D',
#   'AH0',
#   'N',
#   'M',
#   'AH0',
#   'N',
#   'T',
#   'S'],
#  ['abandonments',
#   'AH0',
#   'B',
#   'AE1',
#   'N',
#   'D',
#   'AH0',
#   'N',
#   'M',
#   'AH0',
#   'N',
#   'T',
#   'S',
#   'stop'],
#  ['abandons', 'AH0'],
#  ['abandons', 'AH0', 'B'],
#  ['abandons', 'AH0', 'B', 'AE1'],
#  ['abandons', 'AH0', 'B', 'AE1', 'N'],
#  ['abandons', 'AH0', 'B', 'AE1', 'N', 'D'],
#  ['abandons', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0'],
#  ['abandons', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N'],
#  ['abandons', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'Z'],
#  ['abandons', 'AH0', 'B', 'AE1', 'N', 'D', 'AH0', 'N', 'Z', 'stop'],
#  ['abanto', 'AH0'],
#  ['abanto', 'AH0', 'B'],
#  ['abanto', 'AH0', 'B', 'AE1'],
#  ['abanto', 'AH0', 'B', 'AE1', 'N'],
#  ['abanto', 'AH0', 'B', 'AE1', 'N', 'T'],
#  ['abanto', 'AH0', 'B', 'AE1', 'N', 'T', 'OW0'],
#  ['abanto', 'AH0', 'B', 'AE1', 'N', 'T', 'OW0', 'stop'],
#  ['abarca', 'AH0'],
#  ['abarca', 'AH0', 'B'],
#  ['abarca', 'AH0', 'B', 'AA1'],
#  ['abarca', 'AH0', 'B', 'AA1', 'R'],
#  ['abarca', 'AH0', 'B', 'AA1', 'R', 'K'],
#  ['abarca', 'AH0', 'B', 'AA1', 'R', 'K', 'AH0'],
#  ['abarca', 'AH0', 'B', 'AA1', 'R', 'K', 'AH0', 'stop'],
#  ['abare', 'AA0'],
#  ['abare', 'AA0', 'B'],
#  ['abare', 'AA0', 'B', 'AA1'],
#  ['abare', 'AA0', 'B', 'AA1', 'R'],
#  ['abare', 'AA0', 'B', 'AA1', 'R', 'IY0'],
#  ['abare', 'AA0', 'B', 'AA1', 'R', 'IY0', 'stop'],
#  ['abascal', 'AE1'],
#  ['abascal', 'AE1', 'B'],
#  ['abascal', 'AE1', 'B', 'AH0'],
#  ['abascal', 'AE1', 'B', 'AH0', 'S'],
#  ['abascal', 'AE1', 'B', 'AH0', 'S', 'K'],
#  ['abascal', 'AE1', 'B', 'AH0', 'S', 'K', 'AH0'],
#  ['abascal', 'AE1', 'B', 'AH0', 'S', 'K', 'AH0', 'L'],
#  ['abascal', 'AE1', 'B', 'AH0', 'S', 'K', 'AH0', 'L', 'stop'],
#  ['abash', 'AH0'],
#  ['abash', 'AH0', 'B'],
#  ['abash', 'AH0', 'B', 'AE1'],
#  ['abash', 'AH0', 'B', 'AE1', 'SH'],
#  ['abash', 'AH0', 'B', 'AE1', 'SH', 'stop'],
#  ['abashed', 'AH0'],
#  ['abashed', 'AH0', 'B'],
#  ['abashed', 'AH0', 'B', 'AE1'],
#  ['abashed', 'AH0', 'B', 'AE1', 'SH'],
#  ['abashed', 'AH0', 'B', 'AE1', 'SH', 'T'],
#  ['abashed', 'AH0', 'B', 'AE1', 'SH', 'T', 'stop'],
#  ['abasia', 'AH0'],
#  ['abasia', 'AH0', 'B'],
#  ['abasia', 'AH0', 'B', 'EY1'],
#  ['abasia', 'AH0', 'B', 'EY1', 'ZH'],
#  ['abasia', 'AH0', 'B', 'EY1', 'ZH', 'Y'],
#  ['abasia', 'AH0', 'B', 'EY1', 'ZH', 'Y', 'AH0'],
#  ['abasia', 'AH0', 'B', 'EY1', 'ZH', 'Y', 'AH0', 'stop'],
#  ['abate', 'AH0'],
#  ['abate', 'AH0', 'B'],
#  ['abate', 'AH0', 'B', 'EY1'],
#  ['abate', 'AH0', 'B', 'EY1', 'T'],
#  ['abate', 'AH0', 'B', 'EY1', 'T', 'stop'],
#  ['abated', 'AH0'],
#  ['abated', 'AH0', 'B'],
#  ['abated', 'AH0', 'B', 'EY1'],
#  ['abated', 'AH0', 'B', 'EY1', 'T'],
#  ['abated', 'AH0', 'B', 'EY1', 'T', 'IH0'],
#  ['abated', 'AH0', 'B', 'EY1', 'T', 'IH0', 'D'],
#  ['abated', 'AH0', 'B', 'EY1', 'T', 'IH0', 'D', 'stop'],
#  ['abatement', 'AH0'],
#  ['abatement', 'AH0', 'B'],
#  ['abatement', 'AH0', 'B', 'EY1'],
#  ['abatement', 'AH0', 'B', 'EY1', 'T'],
#  ['abatement', 'AH0', 'B', 'EY1', 'T', 'M'],
#  ['abatement', 'AH0', 'B', 'EY1', 'T', 'M', 'AH0'],
#  ['abatement', 'AH0', 'B', 'EY1', 'T', 'M', 'AH0', 'N'],
#  ['abatement', 'AH0', 'B', 'EY1', 'T', 'M', 'AH0', 'N', 'T'],
#  ['abatement', 'AH0', 'B', 'EY1', 'T', 'M', 'AH0', 'N', 'T', 'stop'],
#  ['abatements', 'AH0'],
#  ['abatements', 'AH0', 'B'],
#  ['abatements', 'AH0', 'B', 'EY1'],
#  ['abatements', 'AH0', 'B', 'EY1', 'T'],
#  ['abatements', 'AH0', 'B', 'EY1', 'T', 'M'],
#  ['abatements', 'AH0', 'B', 'EY1', 'T', 'M', 'AH0'],
#  ['abatements', 'AH0', 'B', 'EY1', 'T', 'M', 'AH0', 'N'],
#  ['abatements', 'AH0', 'B', 'EY1', 'T', 'M', 'AH0', 'N', 'T'],
#  ['abatements', 'AH0', 'B', 'EY1', 'T', 'M', 'AH0', 'N', 'T', 'S'],
#  ['abatements', 'AH0', 'B', 'EY1', 'T', 'M', 'AH0', 'N', 'T', 'S', 'stop'],
#  ['abates', 'AH0'],
#  ['abates', 'AH0', 'B'],
#  ['abates', 'AH0', 'B', 'EY1'],
#  ['abates', 'AH0', 'B', 'EY1', 'T'],
#  ['abates', 'AH0', 'B', 'EY1', 'T', 'S'],
#  ['abates', 'AH0', 'B', 'EY1', 'T', 'S', 'stop'],
#  ['abating', 'AH0'],
#  ['abating', 'AH0', 'B'],
#  ['abating', 'AH0', 'B', 'EY1'],
#  ['abating', 'AH0', 'B', 'EY1', 'T'],
#  ['abating', 'AH0', 'B', 'EY1', 'T', 'IH0'],
#  ['abating', 'AH0', 'B', 'EY1', 'T', 'IH0', 'NG'],
#  ['abating', 'AH0', 'B', 'EY1', 'T', 'IH0', 'NG', 'stop'],
#  ['abattoir', 'AE2'],
#  ['abattoir', 'AE2', 'B'],
#  ['abattoir', 'AE2', 'B', 'AH0'],
#  ['abattoir', 'AE2', 'B', 'AH0', 'T'],
#  ['abattoir', 'AE2', 'B', 'AH0', 'T', 'W'],
#  ['abattoir', 'AE2', 'B', 'AH0', 'T', 'W', 'AA1'],
#  ['abattoir', 'AE2', 'B', 'AH0', 'T', 'W', 'AA1', 'R'],
#  ['abattoir', 'AE2', 'B', 'AH0', 'T', 'W', 'AA1', 'R', 'stop'],
#  ['abba', 'AE1'],
#  ['abba', 'AE1', 'B'],
#  ['abba', 'AE1', 'B', 'AH0'],
#  ['abba', 'AE1', 'B', 'AH0', 'stop'],
#  ['abbado', 'AH0'],
#  ['abbado', 'AH0', 'B'],
#  ['abbado', 'AH0', 'B', 'AA1'],
#  ['abbado', 'AH0', 'B', 'AA1', 'D'],
#  ['abbado', 'AH0', 'B', 'AA1', 'D', 'OW0'],
#  ['abbado', 'AH0', 'B', 'AA1', 'D', 'OW0', 'stop'],
#  ['abbas', 'AH0'],
#  ['abbas', 'AH0', 'B'],
#  ['abbas', 'AH0', 'B', 'AA1'],
#  ['abbas', 'AH0', 'B', 'AA1', 'S'],
#  ['abbas', 'AH0', 'B', 'AA1', 'S', 'stop'],
#  ['abbasi', 'AA0'],
#  ['abbasi', 'AA0', 'B'],
#  ['abbasi', 'AA0', 'B', 'AA1'],
#  ['abbasi', 'AA0', 'B', 'AA1', 'S'],
#  ['abbasi', 'AA0', 'B', 'AA1', 'S', 'IY0'],
#  ['abbasi', 'AA0', 'B', 'AA1', 'S', 'IY0', 'stop'],
#  ['abbate', 'AA1'],
#  ['abbate', 'AA1', 'B'],
#  ['abbate', 'AA1', 'B', 'EY0'],
#  ['abbate', 'AA1', 'B', 'EY0', 'T'],
#  ['abbate', 'AA1', 'B', 'EY0', 'T', 'stop'],
#  ['abbatiello', 'AA0'],
#  ['abbatiello', 'AA0', 'B'],
#  ['abbatiello', 'AA0', 'B', 'AA0'],
#  ['abbatiello', 'AA0', 'B', 'AA0', 'T'],
#  ['abbatiello', 'AA0', 'B', 'AA0', 'T', 'IY0'],
#  ['abbatiello', 'AA0', 'B', 'AA0', 'T', 'IY0', 'EH1'],
#  ['abbatiello', 'AA0', 'B', 'AA0', 'T', 'IY0', 'EH1', 'L'],
#  ['abbatiello', 'AA0', 'B', 'AA0', 'T', 'IY0', 'EH1', 'L', 'OW0'],
#  ['abbatiello', 'AA0', 'B', 'AA0', 'T', 'IY0', 'EH1', 'L', 'OW0', 'stop'],
#  ['abbe', 'AE1'],
#  ['abbe', 'AE1', 'B'],
#  ['abbe', 'AE1', 'B', 'IY0'],
#  ['abbe', 'AE1', 'B', 'IY0', 'stop'],
#  ['abbe(2)', 'AE0'],
#  ['abbe(2)', 'AE0', 'B'],
#  ['abbe(2)', 'AE0', 'B', 'EY1'],
#  ['abbe(2)', 'AE0', 'B', 'EY1', 'stop'],
#  ['abbenhaus', 'AE1'],
#  ['abbenhaus', 'AE1', 'B'],
#  ['abbenhaus', 'AE1', 'B', 'AH0'],
#  ['abbenhaus', 'AE1', 'B', 'AH0', 'N'],
#  ['abbenhaus', 'AE1', 'B', 'AH0', 'N', 'HH'],
#  ['abbenhaus', 'AE1', 'B', 'AH0', 'N', 'HH', 'AW2'],
#  ['abbenhaus', 'AE1', 'B', 'AH0', 'N', 'HH', 'AW2', 'S'],
#  ['abbenhaus', 'AE1', 'B', 'AH0', 'N', 'HH', 'AW2', 'S', 'stop'],
#  ['abbett', 'AH0'],
#  ['abbett', 'AH0', 'B'],
#  ['abbett', 'AH0', 'B', 'EH1'],
#  ['abbett', 'AH0', 'B', 'EH1', 'T'],
#  ['abbett', 'AH0', 'B', 'EH1', 'T', 'stop'],
#  ['abbeville', 'AE1'],
#  ['abbeville', 'AE1', 'B'],
#  ['abbeville', 'AE1', 'B', 'V'],
#  ['abbeville', 'AE1', 'B', 'V', 'IH0'],
#  ['abbeville', 'AE1', 'B', 'V', 'IH0', 'L'],
#  ['abbeville', 'AE1', 'B', 'V', 'IH0', 'L', 'stop'],
#  ['abbey', 'AE1'],
#  ['abbey', 'AE1', 'B'],
#  ['abbey', 'AE1', 'B', 'IY0'],
#  ['abbey', 'AE1', 'B', 'IY0', 'stop'],
#  ["abbey's", 'AE1'],
#  ["abbey's", 'AE1', 'B'],
#  ["abbey's", 'AE1', 'B', 'IY0'],
#  ["abbey's", 'AE1', 'B', 'IY0', 'Z'],
#  ["abbey's", 'AE1', 'B', 'IY0', 'Z', 'stop'],
#  ['abbie', 'AE1'],
#  ['abbie', 'AE1', 'B'],
#  ['abbie', 'AE1', 'B', 'IY0'],
#  ['abbie', 'AE1', 'B', 'IY0', 'stop'],
#  ['abbitt', 'AE1'],
#  ['abbitt', 'AE1', 'B'],
#  ['abbitt', 'AE1', 'B', 'IH0'],
#  ['abbitt', 'AE1', 'B', 'IH0', 'T'],
#  ['abbitt', 'AE1', 'B', 'IH0', 'T', 'stop'],
#  ['abbot', 'AE1'],
#  ['abbot', 'AE1', 'B'],
#  ['abbot', 'AE1', 'B', 'AH0'],
#  ['abbot', 'AE1', 'B', 'AH0', 'T'],
#  ['abbot', 'AE1', 'B', 'AH0', 'T', 'stop'],
#  ['abbotstown', 'AE1'],
#  ['abbotstown', 'AE1', 'B'],
#  ['abbotstown', 'AE1', 'B', 'AH0'],
#  ['abbotstown', 'AE1', 'B', 'AH0', 'T'],
#  ['abbotstown', 'AE1', 'B', 'AH0', 'T', 'S'],
#  ['abbotstown', 'AE1', 'B', 'AH0', 'T', 'S', 'T'],
#  ['abbotstown', 'AE1', 'B', 'AH0', 'T', 'S', 'T', 'AW1'],
#  ['abbotstown', 'AE1', 'B', 'AH0', 'T', 'S', 'T', 'AW1', 'N'],
#  ['abbotstown', 'AE1', 'B', 'AH0', 'T', 'S', 'T', 'AW1', 'N', 'stop'],
#  ['abbott', 'AE1'],
#  ['abbott', 'AE1', 'B'],
#  ['abbott', 'AE1', 'B', 'AH0'],
#  ['abbott', 'AE1', 'B', 'AH0', 'T'],
#  ['abbott', 'AE1', 'B', 'AH0', 'T', 'stop'],
#  ["abbott's", 'AE1'],
#  ["abbott's", 'AE1', 'B'],
#  ["abbott's", 'AE1', 'B', 'AH0'],
#  ["abbott's", 'AE1', 'B', 'AH0', 'T'],
#  ["abbott's", 'AE1', 'B', 'AH0', 'T', 'S'],
#  ["abbott's", 'AE1', 'B', 'AH0', 'T', 'S', 'stop'],
#  ['abbottstown', 'AE1'],
#  ['abbottstown', 'AE1', 'B'],
#  ['abbottstown', 'AE1', 'B', 'AH0'],
#  ['abbottstown', 'AE1', 'B', 'AH0', 'T'],
#  ['abbottstown', 'AE1', 'B', 'AH0', 'T', 'S'],
#  ['abbottstown', 'AE1', 'B', 'AH0', 'T', 'S', 'T'],
#  ['abbottstown', 'AE1', 'B', 'AH0', 'T', 'S', 'T', 'AW1'],
#  ['abbottstown', 'AE1', 'B', 'AH0', 'T', 'S', 'T', 'AW1', 'N'],
#  ['abbottstown', 'AE1', 'B', 'AH0', 'T', 'S', 'T', 'AW1', 'N', 'stop'],
#  ['abboud', 'AH0'],
#  ['abboud', 'AH0', 'B'],
#  ['abboud', 'AH0', 'B', 'UW1'],
#  ['abboud', 'AH0', 'B', 'UW1', 'D'],
#  ['abboud', 'AH0', 'B', 'UW1', 'D', 'stop'],
#  ['abboud(2)', 'AH0'],
#  ['abboud(2)', 'AH0', 'B'],
#  ['abboud(2)', 'AH0', 'B', 'AW1'],
#  ['abboud(2)', 'AH0', 'B', 'AW1', 'D'],
#  ['abboud(2)', 'AH0', 'B', 'AW1', 'D', 'stop'],
#  ['abbreviate', 'AH0'],
#  ['abbreviate', 'AH0', 'B'],
#  ['abbreviate', 'AH0', 'B', 'R'],
#  ['abbreviate', 'AH0', 'B', 'R', 'IY1'],
#  ['abbreviate', 'AH0', 'B', 'R', 'IY1', 'V'],
#  ['abbreviate', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0'],
#  ['abbreviate', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2'],
#  ['abbreviate', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2', 'T'],
#  ['abbreviate', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2', 'T', 'stop'],
#  ['abbreviated', 'AH0'],
#  ['abbreviated', 'AH0', 'B'],
#  ['abbreviated', 'AH0', 'B', 'R'],
#  ['abbreviated', 'AH0', 'B', 'R', 'IY1'],
#  ['abbreviated', 'AH0', 'B', 'R', 'IY1', 'V'],
#  ['abbreviated', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0'],
#  ['abbreviated', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2'],
#  ['abbreviated', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2', 'T'],
#  ['abbreviated', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2', 'T', 'IH0'],
#  ['abbreviated', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2', 'T', 'IH0', 'D'],
#  ['abbreviated',
#   'AH0',
#   'B',
#   'R',
#   'IY1',
#   'V',
#   'IY0',
#   'EY2',
#   'T',
#   'IH0',
#   'D',
#   'stop'],
#  ['abbreviates', 'AH0'],
#  ['abbreviates', 'AH0', 'B'],
#  ['abbreviates', 'AH0', 'B', 'R'],
#  ['abbreviates', 'AH0', 'B', 'R', 'IY1'],
#  ['abbreviates', 'AH0', 'B', 'R', 'IY1', 'V'],
#  ['abbreviates', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0'],
#  ['abbreviates', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2'],
#  ['abbreviates', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2', 'T'],
#  ['abbreviates', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2', 'T', 'S'],
#  ['abbreviates', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2', 'T', 'S', 'stop'],
#  ['abbreviating', 'AH0'],
#  ['abbreviating', 'AH0', 'B'],
#  ['abbreviating', 'AH0', 'B', 'R'],
#  ['abbreviating', 'AH0', 'B', 'R', 'IY1'],
#  ['abbreviating', 'AH0', 'B', 'R', 'IY1', 'V'],
#  ['abbreviating', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0'],
#  ['abbreviating', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2'],
#  ['abbreviating', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2', 'T'],
#  ['abbreviating', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2', 'T', 'IH0'],
#  ['abbreviating', 'AH0', 'B', 'R', 'IY1', 'V', 'IY0', 'EY2', 'T', 'IH0', 'NG'],
#  ['abbreviating',
#   'AH0',
#   'B',
#   'R',
#   'IY1',
#   'V',
#   'IY0',
#   'EY2',
#   'T',
#   'IH0',
#   'NG',
#   'stop'],
#  ['abbreviation', 'AH0'],
#  ['abbreviation', 'AH0', 'B'],
#  ['abbreviation', 'AH0', 'B', 'R'],
#  ['abbreviation', 'AH0', 'B', 'R', 'IY2'],
#  ['abbreviation', 'AH0', 'B', 'R', 'IY2', 'V'],
#  ['abbreviation', 'AH0', 'B', 'R', 'IY2', 'V', 'IY0'],
#  ['abbreviation', 'AH0', 'B', 'R', 'IY2', 'V', 'IY0', 'EY1'],
#  ['abbreviation', 'AH0', 'B', 'R', 'IY2', 'V', 'IY0', 'EY1', 'SH'],
#  ['abbreviation', 'AH0', 'B', 'R', 'IY2', 'V', 'IY0', 'EY1', 'SH', 'AH0'],
#  ['abbreviation', 'AH0', 'B', 'R', 'IY2', 'V', 'IY0', 'EY1', 'SH', 'AH0', 'N'],
#  ['abbreviation',
#   'AH0',
#   'B',
#   'R',
#   'IY2',
#   'V',
#   'IY0',
#   'EY1',
#   'SH',
#   'AH0',
#   'N',
#   'stop'],
#  ['abbreviations', 'AH0'],
#  ['abbreviations', 'AH0', 'B'],
#  ['abbreviations', 'AH0', 'B', 'R'],
#  ['abbreviations', 'AH0', 'B', 'R', 'IY2'],
#  ['abbreviations', 'AH0', 'B', 'R', 'IY2', 'V'],
#  ['abbreviations', 'AH0', 'B', 'R', 'IY2', 'V', 'IY0'],
#  ['abbreviations', 'AH0', 'B', 'R', 'IY2', 'V', 'IY0', 'EY1'],
#  ['abbreviations', 'AH0', 'B', 'R', 'IY2', 'V', 'IY0', 'EY1', 'SH'],
#  ['abbreviations', 'AH0', 'B', 'R', 'IY2', 'V', 'IY0', 'EY1', 'SH', 'AH0'],
#  ['abbreviations',
#   'AH0',
#   'B',
#   'R',
#   'IY2',
#   'V',
#   'IY0',
#   'EY1',
#   'SH',
#   'AH0',
#   'N'],
#  ['abbreviations',
#   'AH0',
#   'B',
#   'R',
#   'IY2',
#   'V',
#   'IY0',
#   'EY1',
#   'SH',
#   'AH0',
#   'N',
#   'Z'],
#  ['abbreviations',
#   'AH0',
#   'B',
#   'R',
#   'IY2',
#   'V',
#   'IY0',
#   'EY1',
#   'SH',
#   'AH0',
#   'N',
#   'Z',
#   'stop'],
#  ['abbruzzese', 'AA0'],
#  ['abbruzzese', 'AA0', 'B'],
#  ['abbruzzese', 'AA0', 'B', 'R'],
#  ['abbruzzese', 'AA0', 'B', 'R', 'UW0'],
#  ['abbruzzese', 'AA0', 'B', 'R', 'UW0', 'T'],
#  ['abbruzzese', 'AA0', 'B', 'R', 'UW0', 'T', 'S'],
#  ['abbruzzese', 'AA0', 'B', 'R', 'UW0', 'T', 'S', 'EY1'],
#  ['abbruzzese', 'AA0', 'B', 'R', 'UW0', 'T', 'S', 'EY1', 'Z'],
#  ['abbruzzese', 'AA0', 'B', 'R', 'UW0', 'T', 'S', 'EY1', 'Z', 'IY0'],
#  ['abbruzzese', 'AA0', 'B', 'R', 'UW0', 'T', 'S', 'EY1', 'Z', 'IY0', 'stop'],
#  ['abbs', 'AE1'],
#  ['abbs', 'AE1', 'B'],
#  ['abbs', 'AE1', 'B', 'Z'],
#  ['abbs', 'AE1', 'B', 'Z', 'stop'],
#  ['abby', 'AE1'],
#  ['abby', 'AE1', 'B'],
#  ['abby', 'AE1', 'B', 'IY0'],
#  ['abby', 'AE1', 'B', 'IY0', 'stop'],
#  ['abc', 'EY1'],
#  ['abc', 'EY1', 'B'],
#  ['abc', 'EY1', 'B', 'IY2'],
#  ['abc', 'EY1', 'B', 'IY2', 'S'],
#  ['abc', 'EY1', 'B', 'IY2', 'S', 'IY2'],
#  ['abc', 'EY1', 'B', 'IY2', 'S', 'IY2', 'stop'],
#  ["abc's", 'EY1'],
#  ["abc's", 'EY1', 'B'],
#  ["abc's", 'EY1', 'B', 'IY2'],
#  ["abc's", 'EY1', 'B', 'IY2', 'S'],
#  ["abc's", 'EY1', 'B', 'IY2', 'S', 'IY2'],
#  ["abc's", 'EY1', 'B', 'IY2', 'S', 'IY2', 'Z'],
#  ["abc's", 'EY1', 'B', 'IY2', 'S', 'IY2', 'Z', 'stop'],
#  ['abco', 'AE1'],
#  ['abco', 'AE1', 'B'],
#  ['abco', 'AE1', 'B', 'K'],
#  ['abco', 'AE1', 'B', 'K', 'OW0'],
#  ['abco', 'AE1', 'B', 'K', 'OW0', 'stop'],
#  ['abcotek', 'AE1'],
#  ['abcotek', 'AE1', 'B'],
#  ['abcotek', 'AE1', 'B', 'K'],
#  ['abcotek', 'AE1', 'B', 'K', 'OW0'],
#  ['abcotek', 'AE1', 'B', 'K', 'OW0', 'T'],
#  ['abcotek', 'AE1', 'B', 'K', 'OW0', 'T', 'EH2'],
#  ['abcotek', 'AE1', 'B', 'K', 'OW0', 'T', 'EH2', 'K'],
#  ['abcotek', 'AE1', 'B', 'K', 'OW0', 'T', 'EH2', 'K', 'stop'],
#  ['abcs', 'EY1'],
#  ['abcs', 'EY1', 'B'],
#  ['abcs', 'EY1', 'B', 'IY2'],
#  ['abcs', 'EY1', 'B', 'IY2', 'S'],
#  ['abcs', 'EY1', 'B', 'IY2', 'S', 'IY2'],
#  ['abcs', 'EY1', 'B', 'IY2', 'S', 'IY2', 'Z'],
#  ['abcs', 'EY1', 'B', 'IY2', 'S', 'IY2', 'Z', 'stop'],
#  ['abd', 'EY2'],
#  ['abd', 'EY2', 'B'],
#  ['abd', 'EY2', 'B', 'IY2'],
#  ['abd', 'EY2', 'B', 'IY2', 'D'],
#  ['abd', 'EY2', 'B', 'IY2', 'D', 'IY1'],
#  ['abd', 'EY2', 'B', 'IY2', 'D', 'IY1', 'stop'],
#  ['abdalla', 'AE2'],
#  ['abdalla', 'AE2', 'B'],
#  ['abdalla', 'AE2', 'B', 'D'],
#  ['abdalla', 'AE2', 'B', 'D', 'AE1'],
#  ['abdalla', 'AE2', 'B', 'D', 'AE1', 'L'],
#  ['abdalla', 'AE2', 'B', 'D', 'AE1', 'L', 'AH0'],
#  ['abdalla', 'AE2', 'B', 'D', 'AE1', 'L', 'AH0', 'stop'],
#  ['abdallah', 'AE2'],
#  ['abdallah', 'AE2', 'B'],
#  ['abdallah', 'AE2', 'B', 'D'],
#  ['abdallah', 'AE2', 'B', 'D', 'AE1'],
#  ['abdallah', 'AE2', 'B', 'D', 'AE1', 'L'],
#  ['abdallah', 'AE2', 'B', 'D', 'AE1', 'L', 'AH0'],
#  ['abdallah', 'AE2', 'B', 'D', 'AE1', 'L', 'AH0', 'stop'],
#  ['abdel', 'AE1'],
#  ['abdel', 'AE1', 'B'],
#  ['abdel', 'AE1', 'B', 'D'],
#  ['abdel', 'AE1', 'B', 'D', 'EH2'],
#  ['abdel', 'AE1', 'B', 'D', 'EH2', 'L'],
#  ['abdel', 'AE1', 'B', 'D', 'EH2', 'L', 'stop'],
#  ['abdella', 'AE2'],
#  ['abdella', 'AE2', 'B'],
#  ['abdella', 'AE2', 'B', 'D'],
#  ['abdella', 'AE2', 'B', 'D', 'EH1'],
#  ['abdella', 'AE2', 'B', 'D', 'EH1', 'L'],
#  ['abdella', 'AE2', 'B', 'D', 'EH1', 'L', 'AH0'],
#  ['abdella', 'AE2', 'B', 'D', 'EH1', 'L', 'AH0', 'stop'],
#  ['abdicate', 'AE1'],
#  ['abdicate', 'AE1', 'B'],
#  ['abdicate', 'AE1', 'B', 'D'],
#  ['abdicate', 'AE1', 'B', 'D', 'AH0'],
#  ['abdicate', 'AE1', 'B', 'D', 'AH0', 'K'],
#  ['abdicate', 'AE1', 'B', 'D', 'AH0', 'K', 'EY2'],
#  ['abdicate', 'AE1', 'B', 'D', 'AH0', 'K', 'EY2', 'T'],
#  ['abdicate', 'AE1', 'B', 'D', 'AH0', 'K', 'EY2', 'T', 'stop'],
#  ['abdicated', 'AE1'],
#  ['abdicated', 'AE1', 'B'],
#  ['abdicated', 'AE1', 'B', 'D'],
#  ['abdicated', 'AE1', 'B', 'D', 'AH0'],
#  ['abdicated', 'AE1', 'B', 'D', 'AH0', 'K'],
#  ['abdicated', 'AE1', 'B', 'D', 'AH0', 'K', 'EY2'],
#  ['abdicated', 'AE1', 'B', 'D', 'AH0', 'K', 'EY2', 'T'],
#  ['abdicated', 'AE1', 'B', 'D', 'AH0', 'K', 'EY2', 'T', 'IH0'],
#  ['abdicated', 'AE1', 'B', 'D', 'AH0', 'K', 'EY2', 'T', 'IH0', 'D'],
#  ['abdicated', 'AE1', 'B', 'D', 'AH0', 'K', 'EY2', 'T', 'IH0', 'D', 'stop'],
#  ['abdicates', 'AE1'],
#  ['abdicates', 'AE1', 'B'],
#  ['abdicates', 'AE1', 'B', 'D'],
#  ['abdicates', 'AE1', 'B', 'D', 'AH0'],
#  ['abdicates', 'AE1', 'B', 'D', 'AH0', 'K'],
#  ['abdicates', 'AE1', 'B', 'D', 'AH0', 'K', 'EY2'],
#  ['abdicates', 'AE1', 'B', 'D', 'AH0', 'K', 'EY2', 'T'],
#  ['abdicates', 'AE1', 'B', 'D', 'AH0', 'K', 'EY2', 'T', 'S'],
#  ['abdicates', 'AE1', 'B', 'D', 'AH0', 'K', 'EY2', 'T', 'S', 'stop'],
#  ['abdicating', 'AE1'],
#  ['abdicating', 'AE1', 'B'],
#  ['abdicating', 'AE1', 'B', 'D'],
#  ['abdicating', 'AE1', 'B', 'D', 'IH0'],
#  ['abdicating', 'AE1', 'B', 'D', 'IH0', 'K'],
#  ['abdicating', 'AE1', 'B', 'D', 'IH0', 'K', 'EY2'],
#  ['abdicating', 'AE1', 'B', 'D', 'IH0', 'K', 'EY2', 'T'],
#  ['abdicating', 'AE1', 'B', 'D', 'IH0', 'K', 'EY2', 'T', 'IH0'],
#  ['abdicating', 'AE1', 'B', 'D', 'IH0', 'K', 'EY2', 'T', 'IH0', 'NG'],
#  ['abdicating', 'AE1', 'B', 'D', 'IH0', 'K', 'EY2', 'T', 'IH0', 'NG', 'stop'],
#  ['abdication', 'AE2'],
#  ['abdication', 'AE2', 'B'],
#  ['abdication', 'AE2', 'B', 'D'],
#  ['abdication', 'AE2', 'B', 'D', 'IH0'],
#  ['abdication', 'AE2', 'B', 'D', 'IH0', 'K'],
#  ['abdication', 'AE2', 'B', 'D', 'IH0', 'K', 'EY1'],
#  ['abdication', 'AE2', 'B', 'D', 'IH0', 'K', 'EY1', 'SH'],
#  ['abdication', 'AE2', 'B', 'D', 'IH0', 'K', 'EY1', 'SH', 'AH0'],
#  ['abdication', 'AE2', 'B', 'D', 'IH0', 'K', 'EY1', 'SH', 'AH0', 'N'],
#  ['abdication', 'AE2', 'B', 'D', 'IH0', 'K', 'EY1', 'SH', 'AH0', 'N', 'stop'],
#  ['abdnor', 'AE1'],
#  ['abdnor', 'AE1', 'B'],
#  ['abdnor', 'AE1', 'B', 'D'],
#  ['abdnor', 'AE1', 'B', 'D', 'N'],
#  ['abdnor', 'AE1', 'B', 'D', 'N', 'ER0'],
#  ['abdnor', 'AE1', 'B', 'D', 'N', 'ER0', 'stop'],
#  ['abdo', 'AE1'],
#  ['abdo', 'AE1', 'B'],
#  ['abdo', 'AE1', 'B', 'D'],
#  ['abdo', 'AE1', 'B', 'D', 'OW0'],
#  ['abdo', 'AE1', 'B', 'D', 'OW0', 'stop'],
#  ['abdollah', 'AE2'],
#  ['abdollah', 'AE2', 'B'],
#  ['abdollah', 'AE2', 'B', 'D'],
#  ['abdollah', 'AE2', 'B', 'D', 'AA1'],
#  ['abdollah', 'AE2', 'B', 'D', 'AA1', 'L'],
#  ['abdollah', 'AE2', 'B', 'D', 'AA1', 'L', 'AH0'],
#  ['abdollah', 'AE2', 'B', 'D', 'AA1', 'L', 'AH0', 'stop'],
#  ['abdomen', 'AE0'],
#  ['abdomen', 'AE0', 'B'],
#  ['abdomen', 'AE0', 'B', 'D'],
#  ['abdomen', 'AE0', 'B', 'D', 'OW1'],
#  ['abdomen', 'AE0', 'B', 'D', 'OW1', 'M'],
#  ['abdomen', 'AE0', 'B', 'D', 'OW1', 'M', 'AH0'],
#  ['abdomen', 'AE0', 'B', 'D', 'OW1', 'M', 'AH0', 'N'],
#  ['abdomen', 'AE0', 'B', 'D', 'OW1', 'M', 'AH0', 'N', 'stop'],
#  ['abdomen(2)', 'AE1'],
#  ['abdomen(2)', 'AE1', 'B'],
#  ['abdomen(2)', 'AE1', 'B', 'D'],
#  ['abdomen(2)', 'AE1', 'B', 'D', 'AH0'],
#  ['abdomen(2)', 'AE1', 'B', 'D', 'AH0', 'M'],
#  ['abdomen(2)', 'AE1', 'B', 'D', 'AH0', 'M', 'AH0'],
#  ['abdomen(2)', 'AE1', 'B', 'D', 'AH0', 'M', 'AH0', 'N'],
#  ['abdomen(2)', 'AE1', 'B', 'D', 'AH0', 'M', 'AH0', 'N', 'stop'],
#  ['abdominal', 'AE0'],
#  ['abdominal', 'AE0', 'B'],
#  ['abdominal', 'AE0', 'B', 'D'],
#  ['abdominal', 'AE0', 'B', 'D', 'AA1'],
#  ['abdominal', 'AE0', 'B', 'D', 'AA1', 'M'],
#  ['abdominal', 'AE0', 'B', 'D', 'AA1', 'M', 'AH0'],
#  ['abdominal', 'AE0', 'B', 'D', 'AA1', 'M', 'AH0', 'N'],
#  ['abdominal', 'AE0', 'B', 'D', 'AA1', 'M', 'AH0', 'N', 'AH0'],
#  ['abdominal', 'AE0', 'B', 'D', 'AA1', 'M', 'AH0', 'N', 'AH0', 'L'],
#  ['abdominal', 'AE0', 'B', 'D', 'AA1', 'M', 'AH0', 'N', 'AH0', 'L', 'stop'],
#  ['abdominal(2)', 'AH0'],
#  ['abdominal(2)', 'AH0', 'B'],
#  ['abdominal(2)', 'AH0', 'B', 'D'],
#  ['abdominal(2)', 'AH0', 'B', 'D', 'AA1'],
#  ['abdominal(2)', 'AH0', 'B', 'D', 'AA1', 'M'],
#  ['abdominal(2)', 'AH0', 'B', 'D', 'AA1', 'M', 'AH0'],
#  ['abdominal(2)', 'AH0', 'B', 'D', 'AA1', 'M', 'AH0', 'N'],
#  ['abdominal(2)', 'AH0', 'B', 'D', 'AA1', 'M', 'AH0', 'N', 'AH0'],
#  ['abdominal(2)', 'AH0', 'B', 'D', 'AA1', 'M', 'AH0', 'N', 'AH0', 'L'],
#  ['abdominal(2)', 'AH0', 'B', 'D', 'AA1', 'M', 'AH0', 'N', 'AH0', 'L', 'stop'],
#  ['abduct', 'AE0'],
#  ['abduct', 'AE0', 'B'],
#  ['abduct', 'AE0', 'B', 'D'],
#  ['abduct', 'AE0', 'B', 'D', 'AH1'],
#  ['abduct', 'AE0', 'B', 'D', 'AH1', 'K'],
#  ['abduct', 'AE0', 'B', 'D', 'AH1', 'K', 'T'],
#  ['abduct', 'AE0', 'B', 'D', 'AH1', 'K', 'T', 'stop'],
#  ['abducted', 'AE0'],
#  ['abducted', 'AE0', 'B'],
#  ['abducted', 'AE0', 'B', 'D'],
#  ['abducted', 'AE0', 'B', 'D', 'AH1'],
#  ['abducted', 'AE0', 'B', 'D', 'AH1', 'K'],
#  ['abducted', 'AE0', 'B', 'D', 'AH1', 'K', 'T'],
#  ['abducted', 'AE0', 'B', 'D', 'AH1', 'K', 'T', 'IH0'],
#  ['abducted', 'AE0', 'B', 'D', 'AH1', 'K', 'T', 'IH0', 'D'],
#  ['abducted', 'AE0', 'B', 'D', 'AH1', 'K', 'T', 'IH0', 'D', 'stop'],
#  ['abducted(2)', 'AH0'],
#  ['abducted(2)', 'AH0', 'B'],
#  ['abducted(2)', 'AH0', 'B', 'D'],
#  ['abducted(2)', 'AH0', 'B', 'D', 'AH1'],
#  ['abducted(2)', 'AH0', 'B', 'D', 'AH1', 'K'],
#  ['abducted(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'T'],
#  ['abducted(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'T', 'IH0'],
#  ['abducted(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'T', 'IH0', 'D'],
#  ['abducted(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'T', 'IH0', 'D', 'stop'],
#  ['abductee', 'AE0'],
#  ['abductee', 'AE0', 'B'],
#  ['abductee', 'AE0', 'B', 'D'],
#  ['abductee', 'AE0', 'B', 'D', 'AH2'],
#  ['abductee', 'AE0', 'B', 'D', 'AH2', 'K'],
#  ['abductee', 'AE0', 'B', 'D', 'AH2', 'K', 'T'],
#  ['abductee', 'AE0', 'B', 'D', 'AH2', 'K', 'T', 'IY1'],
#  ['abductee', 'AE0', 'B', 'D', 'AH2', 'K', 'T', 'IY1', 'stop'],
#  ['abductees', 'AE0'],
#  ['abductees', 'AE0', 'B'],
#  ['abductees', 'AE0', 'B', 'D'],
#  ['abductees', 'AE0', 'B', 'D', 'AH2'],
#  ['abductees', 'AE0', 'B', 'D', 'AH2', 'K'],
#  ['abductees', 'AE0', 'B', 'D', 'AH2', 'K', 'T'],
#  ['abductees', 'AE0', 'B', 'D', 'AH2', 'K', 'T', 'IY1'],
#  ['abductees', 'AE0', 'B', 'D', 'AH2', 'K', 'T', 'IY1', 'Z'],
#  ['abductees', 'AE0', 'B', 'D', 'AH2', 'K', 'T', 'IY1', 'Z', 'stop'],
#  ['abducting', 'AE0'],
#  ['abducting', 'AE0', 'B'],
#  ['abducting', 'AE0', 'B', 'D'],
#  ['abducting', 'AE0', 'B', 'D', 'AH1'],
#  ['abducting', 'AE0', 'B', 'D', 'AH1', 'K'],
#  ['abducting', 'AE0', 'B', 'D', 'AH1', 'K', 'T'],
#  ['abducting', 'AE0', 'B', 'D', 'AH1', 'K', 'T', 'IH0'],
#  ['abducting', 'AE0', 'B', 'D', 'AH1', 'K', 'T', 'IH0', 'NG'],
#  ['abducting', 'AE0', 'B', 'D', 'AH1', 'K', 'T', 'IH0', 'NG', 'stop'],
#  ['abducting(2)', 'AH0'],
#  ['abducting(2)', 'AH0', 'B'],
#  ['abducting(2)', 'AH0', 'B', 'D'],
#  ['abducting(2)', 'AH0', 'B', 'D', 'AH1'],
#  ['abducting(2)', 'AH0', 'B', 'D', 'AH1', 'K'],
#  ['abducting(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'T'],
#  ['abducting(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'T', 'IH0'],
#  ['abducting(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'T', 'IH0', 'NG'],
#  ['abducting(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'T', 'IH0', 'NG', 'stop'],
#  ['abduction', 'AE0'],
#  ['abduction', 'AE0', 'B'],
#  ['abduction', 'AE0', 'B', 'D'],
#  ['abduction', 'AE0', 'B', 'D', 'AH1'],
#  ['abduction', 'AE0', 'B', 'D', 'AH1', 'K'],
#  ['abduction', 'AE0', 'B', 'D', 'AH1', 'K', 'SH'],
#  ['abduction', 'AE0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0'],
#  ['abduction', 'AE0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0', 'N'],
#  ['abduction', 'AE0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0', 'N', 'stop'],
#  ['abduction(2)', 'AH0'],
#  ['abduction(2)', 'AH0', 'B'],
#  ['abduction(2)', 'AH0', 'B', 'D'],
#  ['abduction(2)', 'AH0', 'B', 'D', 'AH1'],
#  ['abduction(2)', 'AH0', 'B', 'D', 'AH1', 'K'],
#  ['abduction(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'SH'],
#  ['abduction(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0'],
#  ['abduction(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0', 'N'],
#  ['abduction(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0', 'N', 'stop'],
#  ['abductions', 'AE0'],
#  ['abductions', 'AE0', 'B'],
#  ['abductions', 'AE0', 'B', 'D'],
#  ['abductions', 'AE0', 'B', 'D', 'AH1'],
#  ['abductions', 'AE0', 'B', 'D', 'AH1', 'K'],
#  ['abductions', 'AE0', 'B', 'D', 'AH1', 'K', 'SH'],
#  ['abductions', 'AE0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0'],
#  ['abductions', 'AE0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0', 'N'],
#  ['abductions', 'AE0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0', 'N', 'Z'],
#  ['abductions', 'AE0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0', 'N', 'Z', 'stop'],
#  ['abductions(2)', 'AH0'],
#  ['abductions(2)', 'AH0', 'B'],
#  ['abductions(2)', 'AH0', 'B', 'D'],
#  ['abductions(2)', 'AH0', 'B', 'D', 'AH1'],
#  ['abductions(2)', 'AH0', 'B', 'D', 'AH1', 'K'],
#  ['abductions(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'SH'],
#  ['abductions(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0'],
#  ['abductions(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0', 'N'],
#  ['abductions(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0', 'N', 'Z'],
#  ['abductions(2)', 'AH0', 'B', 'D', 'AH1', 'K', 'SH', 'AH0', 'N', 'Z', 'stop'],
#  ...]

# %%
with open("../datasets/processed_english.dict", "w") as txt_file:
    for line in extended_data:
        txt_file.write(" ".join(line) + "\n")
